# %% [markdown]
# Ingest Data from Silver Tables (csvs) and EndTimeRules

# %%
df_basic = spark.read.format("csv").option("header", "true").load("/Volumes/postnord/default/data/Silver_item_basic_20251222.csv")
display(df_basic.head(5))

# %%
df_scan = spark.read.format("csv").option("header", "true").load("/Volumes/postnord/default/data/Silver_item_scans_20251222.csv")
display(df_scan.head(5))

# %%
df_rules = spark.read.format("excel").option("header", "true").load("/Volumes/postnord/default/data/EndTimeRules.xlsx")
display(df_rules.head(5))
